# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#    Presa  seed validation  Modello scelto  Acc Validation  Acc test  \
# 0      1        109364524              39           79.20     82.69
# 1      3             1234              31           84.09     81.73
# 2      4           132435              39           82.69     80.76
# 3      6            10020              32           77.08     82.69
# 4      7            99978              36           81.25     82.00
# 5      9           665544              37           75.00     79.80
# 6     10           203040              30           77.50     80.76
# 7     11             9182              33           75.00     79.80
# 8     13             6842              32           80.00     77.88
# 9     14           806090              34             NaN       NaN
#
#          Unnamed: 5  ord  auc validation  auc test
# 0    prima x matteo    0             NaN       NaN
# 1    terza x matteo    1           85.87     89.80
# 2   quarta x matteo    2           89.05     84.05
# ...

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

plt.ylim(70, 100)
ax1.grid(color='black', linestyle='-.', linewidth=0.5, alpha=0.3)
color = 'tab:red'
ax1.set_xlabel('CV')
ax1.set_ylabel('ACC (%)', color=color)
ax1.plot(df['Acc Validation'], '-o', linewidth=3, markersize=9, color=color, label='ACC Validation')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

plt.ylim(70, 100)
color = 'tab:blue'
ax2.set_ylabel('AUC (%)', color=color)  # we already handled the x-label with ax1
ax2.plot(df['auc validation'],'-^', linewidth=3, markersize=13, color=color, label='AUC Validation')
ax2.tick_params(axis='y', labelcolor=color)

ax1.spines['top'].set_visible(False)
ax2.spines['top'].set_visible(False)
fig.legend()
fig.tight_layout()  # otherwise the right y-label is slightly clipped
#plt.show()
plt.savefig('Validation.png')

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

plt.ylim(70, 100)
ax1.grid(color='black', linestyle='-.', linewidth=0.5, alpha=0.3)
color = 'tab:red'
ax1.set_xlabel('CV')
ax1.set_ylabel('ACC (%)', color=color)
ax1.plot(df['Acc test'], '-o', linewidth=3, markersize=9, color=color, label='ACC Test')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

plt.ylim(70, 100)
color = 'tab:blue'
ax2.set_ylabel('AUC (%)', color=color)  # we already handled the x-label with ax1
ax2.plot(df['auc test'],'-^', linewidth=3, markersize=13, color=color, label='AUC Test')
ax2.tick_params(axis='y', labelcolor=color)

ax1.spines['top'].set_visible(False)
ax2.spines['top'].set_visible(False)
fig.legend()
fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.savefig('Test.png')

# %%
df = pd.read_excel('res_10.ods', engine='odf')

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.grid(color='black', linestyle='-.', linewidth=0.5, alpha=0.3)
plt.ylim(40, 100)
plt.xlim(-0.4, 9.4)
plt.plot(df['Acc Validation'], '-o', linewidth=3, markersize=9, label='Validation')
plt.plot(df['Acc test'], '-o', linewidth=3, markersize=9, label='Test')
plt.ylabel('ACC (%)')
plt.xlabel('CV')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend()

# %%
df
# Out:
#    Presa  seed validation  Modello scelto  Acc Validation  Acc test  \
# 0      1        109364524              39           79.20     82.69
# 1      3             1234              31           84.09     81.73
# 2      4           132435              39           82.69     80.76
# 3      6            10020              32           77.08     82.69
# 4      7            99978              36           81.25     82.00
# 5      9           665544              37           75.00     79.80
# 6     10           203040              30           77.50     80.76
# 7     11             9182              33           75.00     79.80
# 8     13             6842              32           80.00     77.88
# 9     14           806090              34           80.00     79.80
#
#          Unnamed: 5  ord  auc validation  auc test
# 0    prima x matteo    0             NaN       NaN
# 1    terza x matteo    1           85.87     89.80
# 2   quarta x matteo    2           89.05     84.05
# ...
